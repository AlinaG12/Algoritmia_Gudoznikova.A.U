# %%
import openpyxl
from docxtpl import DocxTemplate
template_path = ('/content/drive/MyDrive/algoritm/proekt/shablon.docx')
templated = DocxTemplate(template_path)
print(templated)
wb = openpyxl.load_workbook('/content/drive/MyDrive/algoritm/proekt/dannie.xlsx')
sheet = wb['Лист1']
print(sheet.rows)
for row in range(2,3):
    predmet = sheet['A' + str(row)].value
    nomer = sheet['B' + str(row)].value
    kurs = sheet['C' + str(row)].value
    semestr = sheet['D' + str(row)].value
    specialnost = sheet['E' + str(row)].value
    fio_prepod = sheet['F' + str(row)].value
    students = sheet['G' + str(row)].value
    propusk = sheet['H' + str(row)].value
    hour1 = sheet['I' + str(row)].value
    hour2 = sheet['J' + str(row)].value
    min1 = sheet['K' + str(row)].value
    min2 = sheet['L' + str(row)].value
    p = sheet['M' + str(row)].value
    p1 = sheet['N' + str(row)].value
    p2 = sheet['O' + str(row)].value
    p3 = sheet['P' + str(row)].value
    p4 = sheet['Q' + str(row)].value
    p5 = sheet['R' + str(row)].value
    p6 = sheet['S' + str(row)].value
    p7 = sheet['T' + str(row)].value
    p8 = sheet['U' + str(row)].value
    p9 = sheet['V' + str(row)].value
    p10 = sheet['W' + str(row)].value
    p11 = sheet['X' + str(row)].value
    p12 = sheet['Y' + str(row)].value
    p13 = sheet['Z' + str(row)].value
    p14 = sheet['AA' + str(row)].value
    p15 = sheet['AB' + str(row)].value
    p16 = sheet['AC' + str(row)].value
    p17 = sheet['AD' + str(row)].value
    p18 = sheet['AE' + str(row)].value
    p19 = sheet['AF' + str(row)].value
    p20 = sheet['AG' + str(row)].value
    p21 = sheet['AH' + str(row)].value
    p22 = sheet['AI' + str(row)].value
    p23 = sheet['AJ' + str(row)].value
    p24 = sheet['AK' + str(row)].value
    p25 = sheet['AL' + str(row)].value
    bilet = sheet['AM' + str(row)].value
    bilet1 = sheet['AN' + str(row)].value
    bilet2 = sheet['AO' + str(row)].value
    bilet3 = sheet['AP' + str(row)].value
    bilet4 = sheet['AQ' + str(row)].value
    bilet5 = sheet['AR' + str(row)].value
    bilet6 = sheet['AS' + str(row)].value
    bilet7 = sheet['AT' + str(row)].value
    bilet8 = sheet['AU' + str(row)].value
    bilet9 = sheet['AV' + str(row)].value
    bilet10 = sheet['AW' + str(row)].value
    bilet11 = sheet['AX' + str(row)].value
    bilet12 = sheet['AY' + str(row)].value
    bilet13 = sheet['AZ' + str(row)].value
    bilet14 = sheet['BA' + str(row)].value
    bilet15 = sheet['BB' + str(row)].value
    bilet16 = sheet['BC' + str(row)].value
    bilet17 = sheet['BD' + str(row)].value
    bilet18 = sheet['BE' + str(row)].value
    bilet19 = sheet['BF' + str(row)].value
    bilet20 = sheet['BG' + str(row)].value
    bilet21 = sheet['BH' + str(row)].value
    bilet22 = sheet['BI' + str(row)].value
    bilet23 = sheet['BJ' + str(row)].value
    bilet24 = sheet['BK' + str(row)].value
    bilet25 = sheet['BL' + str(row)].value
    exammen = sheet['BM' + str(row)].value
    exammen1 = sheet['BN' + str(row)].value
    exammen2 = sheet['BO' + str(row)].value
    exammen3 = sheet['BP' + str(row)].value
    exammen4 = sheet['BQ' + str(row)].value
    exammen5 = sheet['BR' + str(row)].value
    exammen6 = sheet['BS' + str(row)].value
    exammen7 = sheet['BT' + str(row)].value
    exammen8 = sheet['BU' + str(row)].value
    exammen9 = sheet['BV' + str(row)].value
    exammen10 = sheet['BW' + str(row)].value
    exammen11 = sheet['BX' + str(row)].value
    exammen12 = sheet['BY' + str(row)].value
    exammen13 = sheet['BZ' + str(row)].value
    exammen14 = sheet['CA' + str(row)].value
    exammen15 = sheet['CB' + str(row)].value
    exammen16 = sheet['CC' + str(row)].value
    exammen17 = sheet['CD' + str(row)].value
    exammen18 = sheet['CE' + str(row)].value
    exammen19 = sheet['CF' + str(row)].value
    exammen20 = sheet['CG' + str(row)].value
    exammen21 = sheet['CH' + str(row)].value
    exammen22 = sheet['CI' + str(row)].value
    exammen23 = sheet['CJ' + str(row)].value
    exammen24 = sheet['CK' + str(row)].value
    exammen25 = sheet['CL' + str(row)].value
    ocenka = sheet['CM' + str(row)].value
    ocenka1 = sheet['CN' + str(row)].value
    ocenka2 = sheet['CO' + str(row)].value
    ocenka3 = sheet['CP' + str(row)].value
    ocenka4 = sheet['CQ' + str(row)].value
    ocenka5 = sheet['CR' + str(row)].value
    ocenka6 = sheet['CS' + str(row)].value
    ocenka7 = sheet['CT' + str(row)].value
    ocenka8 = sheet['CU' + str(row)].value
    ocenka9 = sheet['CV' + str(row)].value
    ocenka10 = sheet['CW' + str(row)].value
    ocenka11 = sheet['CX' + str(row)].value
    ocenka12 = sheet['CY' + str(row)].value
    ocenka13 = sheet['CZ' + str(row)].value
    ocenka14 = sheet['DA' + str(row)].value
    ocenka15 = sheet['DB' + str(row)].value
    ocenka16 = sheet['DC' + str(row)].value
    ocenka17 = sheet['DD' + str(row)].value
    ocenka18 = sheet['DE' + str(row)].value
    ocenka19 = sheet['DF' + str(row)].value
    ocenka20 = sheet['DG' + str(row)].value
    ocenka21 = sheet['DH' + str(row)].value
    ocenka22 = sheet['DI' + str(row)].value
    ocenka23 = sheet['DJ' + str(row)].value
    ocenka24 = sheet['DK' + str(row)].value
    ocenka25 = sheet['DL' + str(row)].value
    ocenka26 = sheet['DM' + str(row)].value
    Mnenia_komisi = sheet['DN' + str(row)].value
    narushenia = sheet['DO' + str(row)].value
    mesyac = sheet['DP' + str(row)].value
    god = sheet['DQ' + str(row)].value
    mesyac1 = sheet['DR' + str(row)].value
    god1 = sheet['DS' + str(row)].value
    prepod = sheet['DT' + str(row)].value
    data = sheet['DU' + str(row)].value
    data1 = sheet['DV' + str(row)].value
    print(predmet, nomer, fio_prepod, kurs, semestr, specialnost, students, propusk, mesyac1, hour1, hour2, min1, min2, p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11,
           p12, p13, p14, p15, p16, p17, p18, p19, p20, p21, p22, p23, p24, p25, exammen, exammen1, exammen2, exammen3, exammen4, exammen5, exammen6, exammen7, exammen8,
           exammen9, exammen10, exammen11, exammen12, exammen13, exammen14, exammen15, exammen16, exammen17, exammen18, exammen19, exammen20, exammen21, exammen22,
           exammen23, exammen24, exammen25, bilet, bilet1, bilet2, bilet3, bilet4, bilet5, bilet6, bilet7, bilet8, bilet9, bilet10, bilet11, bilet12, bilet13, bilet14, bilet15,
           bilet16, bilet17, bilet18, bilet19, bilet20, bilet21, bilet22, bilet23, bilet24, bilet25, ocenka,
           ocenka2, ocenka3, ocenka4, ocenka5, ocenka6, ocenka7, ocenka8, ocenka9, ocenka10, ocenka11, ocenka12, ocenka13, ocenka14,
           ocenka15, ocenka16, ocenka17, ocenka18, ocenka19, ocenka20, ocenka21, ocenka22, ocenka23, ocenka24, ocenka25, ocenka26, Mnenia_komisi, narushenia,
          mesyac, god, god1, data, data1)

    word = {
    'predmet': predmet,
    'nomer': nomer,
    'kurs': kurs,
    'semestr': semestr,
    'specialnost': specialnost,
    'fio_prepod': fio_prepod,
    'students': students,
    'propusk': propusk,
    'hour1': hour1,
    'hour2': hour2,
    'min1': min1,
    'min2': min2,
    'p':p,
    'p1':p1,
    'p2':p2,
    'p3':p3,
    'p4':p4,
    'p5':p5,
    'p6':p6,
    'p7':p7,
    'p8':p8,
    'p9':p9,
    'p10':p10,
    'p11':p11,
    'p12':p12,
    'p13':p13,
    'p14':p14,
    'p15':p15,
    'p16':p16,
    'p17':p17,
    'p18':p18,
    'p19':p19,
    'p20':p20,
    'p21':p21,
    'p22':p22,
    'p23':p23,
    'p24':p24,
    'p25':p25,
    'exammen':exammen,
    'exammen1':exammen1,
    'exammen2':exammen2,
    'exammen3':exammen3,
    'exammen4':exammen4,
    'exammen5':exammen5,
    'exammen6':exammen6,
    'exammen7':exammen7,
    'exammen8':exammen8,
    'exammen9':exammen9,
    'exammen10':exammen10,
    'exammen11':exammen11,
    'exammen12':exammen12,
    'exammen13':exammen13,
    'exammen14':exammen14,
    'exammen15':exammen15,
    'exammen16':exammen16,
    'exammen17':exammen17,
    'exammen18':exammen18,
    'exammen19':exammen19,
    'exammen20':exammen20,
    'exammen21':exammen21,
    'exammen22':exammen22,
    'exammen23':exammen23,
    'exammen24':exammen24,
    'exammen25':exammen25,
    'bilet':bilet,
    'bilet1':bilet1,
    'bilet2':bilet2,
    'bilet3':bilet3,
    'bilet4':bilet4,
    'bilet5':bilet5,
    'bilet6':bilet6,
    'bilet7':bilet7,
    'bilet8':bilet8,
    'bilet9':bilet9,
    'bilet10':bilet10,
    'bilet11':bilet11,
    'bilet12':bilet12,
    'bilet13':bilet13,
    'bilet14':bilet14,
    'bilet15':bilet15,
    'bilet16':bilet16,
    'bilet17':bilet17,
    'bilet18':bilet18,
    'bilet19':bilet19,
    'bilet20':bilet20,
    'bilet21':bilet21,
    'bilet22':bilet22,
    'bilet23':bilet23,
    'bilet24':bilet24,
    'bilet25':bilet25,
    'ocenka':ocenka,
    'ocenka1':ocenka1,
    'ocenka2':ocenka2,
    'ocenka3':ocenka3,
    'ocenka4':ocenka4,
    'ocenka5':ocenka5,
    'ocenka6':ocenka6,
    'ocenka7':ocenka7,
    'ocenka7':ocenka8,
    'ocenka9':ocenka9,
    'ocenka10':ocenka10,
    'ocenka11':ocenka11,
    'ocenka12':ocenka12,
    'ocenka13':ocenka13,
    'ocenka14':ocenka14,
    'ocenka15':ocenka15,
    'ocenka16':ocenka16,
    'ocenka17':ocenka17,
    'ocenka18':ocenka18,
    'ocenka19':ocenka19,
    'ocenka20':ocenka20,
    'ocenka21':ocenka21,
    'ocenka22':ocenka22,
    'ocenka23':ocenka23,
    'ocenka24':ocenka24,
    'ocenka25':ocenka25,
    'Mnenia_komisi': Mnenia_komisi,
    'narushenia': narushenia,
    'mesyac': mesyac,
    'mesyac1': mesyac1,
    'god': god,
    'god1': god1,
    'prepod': prepod,
    'data': data,
    'data1': data1
    }
    output_filename = ('/content/drive/MyDrive/algoritm/proekt/proektNEW.docx')
    templated.render(word)
    templated.save(output_filename)
print('Готово')
# Out:
# ...
# <generator object Worksheet._cells_by_row at 0x7a95e5ad0ac0>
# ...

# %%
pip install openpyxl

# %%
pip install docxtpl
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docxcompose: filename=docxcompose-1.4.0-py3-none-any.whl size=23265 sha256=4a649156f6880bdafede0d9dc2a7814224c296c91015c205441af6f06fb04fe6
#   Stored in directory: /root/.cache/pip/wheels/28/0e/78/2dc28f2d5b192d1a3ec237ec60e9d65654a078dfe07ce3a714
# Successfully built docxcompose
# ...

# %%
pip install python.docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 3.7 MB/s eta 0:00:00
# ...
